# %% [markdown]
# # Homework 1, ADA2020
# ## Task 1: Load the data

# %% [markdown]
# We start with a docstring:

# %%
 '''
 File name: HW1_IB.ipynb
 Author: IB
 Date created: 06/10/2020 (DD/MM/YYYY)
 Date last modified: 06/10/2020 
 Python Version: 3.8.5
 '''
# Out:
# '\nFile name: HW1_IB.ipynb\nAuthor: IB\nDate created: 06/10/2020 (DD/MM/YYYY)\nDate last modified: 06/10/2020 \nPython Version: 3.8.5\n'

# %% [markdown]
# Import libraries:

# %%
import pandas as pd
import pickle

# %%
DATA_PATH = './data/'

ARTICLES_DATA = DATA_PATH+'articles.tsv.gz'
TOPICS_DATA = DATA_PATH+'topics.jsonl.gz'
MAPPING_DATA = DATA_PATH+'mapping.pickle'

COMPRESSION = 'gzip'

# %%
# Read datasets
df_articles = pd.read_csv(ARTICLES_DATA, compression=COMPRESSION,sep='\t', error_bad_lines=False) #error_bad_lines --> drop lines with too many fields
df_topics = pd.read_json(TOPICS_DATA, compression=COMPRESSION, lines=True)
mapping_data = pickle.load(open(MAPPING_DATA, "rb"))
# Out:
# b'Skipping line 7: expected 944 fields, saw 945\n'

# %%
df_articles.head() #to check the dataframe
# Out:
#                           index  2018-01-01 00:00:00  2018-01-02 00:00:00  \
# 0                        Khulna                    0                    2
# 1              Karim_Ansarifard                    1                    5
# 2                        Poldhu                    0                    0
# 3  Alice_(The_Sisters_of_Mercy)                    0                    1
# 4                       Palmyra                    1                    4
#
#    2018-01-03 00:00:00  2018-01-04 00:00:00  2018-01-05 00:00:00  \
# 0                    1                    0                    0
# 1                    1                    1                    1
# 2                    1                    1                    0
# 3                    0                    0                    1
# 4                    0                    0                    0
#
#    2018-01-06 00:00:00  2018-01-07 00:00:00  2018-01-08 00:00:00  \
# ...

# %%
type(df_topics)
# Out:
# pandas.core.frame.DataFrame

# %%
df_topics.head()
# Out:
#                    index  Geography.Regions.Asia.Central Asia  \
# 0   Chinese_food_therapy                                False
# 1      Battle_of_Naissus                                False
# 2  Battle_of_Stoke_Field                                False
# 3            Smooth_newt                                False
# 4     Vicente_Aleixandre                                False
#
#    Geography.Regions.Europe.Eastern Europe  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    History and Society.Military and warfare  Culture.Media.Television  \
# 0                                     False                     False
# 1                                      True                     False
# 2                                      True                     False
# ...

# %%
type(mapping_data)
# Out:
# dict

# %% [markdown]
# ## Task2: Filtering the data

# %%
### Task 2.1 starts here
df_articles.loc[175:185] #check out some lines
# Out:
#                               index  2018-01-01 00:00:00  2018-01-02 00:00:00  \
# 175  Cast_delle_Simpatiche_canaglie                    2                    2
# 176       Juan_Eugenio_Hartzenbusch                    0                    2
# 177                 Lampada_ad_arco                    4                   10
# 178                Achille_Majocchi                    0                    0
# 179                    Olympus_E-P1                    1                    0
# 180              Discussione:Jitter                   21                   41
# 181                Allsvenskan_1997                    0                    0
# 182                           Carmi                    1                    0
# 183                     Else_Alfelt                    0                    0
# 184              New_York_Navy_Yard                    0                    1
# 185                      Kévin_Réza                    0                    2
#
# ...

# %% [markdown]
# Indeed, line 180 seems to be odd. We need to filter them out.

# %%
#Find all lines where index starts with 'Discussione'
df_articles[df_articles['index'].apply(lambda x: x.startswith('Discussione'))]
# Out:
#                                                  index  2018-01-01 00:00:00  \
# 180                                 Discussione:Jitter                   21
# 285          Discussione:Rivoluzione_egiziana_del_1919                    1
# 291                        Discussione:Celebes_editore                    0
# 296       Discussione:First_Rays_of_the_New_Rising_Sun                    3
# 327                             Discussione:Toby_Young                    4
# ...                                                ...                  ...
# 56280  Discussione:Episodi_di_Merlin_(quinta_stagione)                   24
# 56469  Discussione:Liceo_statale_Gian_Domenico_Cassini                    1
# 56511                Discussione:Revolution_Is_My_Name                    0
# 56631            Discussione:Kevin_Macdonald_(regista)                    0
# 56771                     Discussione:José_Pesarrodona                    0
#
# ...

# %%
#Filter bad rows
df_articles_filtered=df_articles[~(df_articles['index'].apply(lambda x: x.startswith('Discussione')))]

# %%
#Find size of unfiltered df
df_articles.shape
# Out:
# (56791, 944)

# %%
# Check size of filtered df
df_articles_filtered.shape
# Out:
# (55791, 944)

# %% [markdown]
# 1000 rows have been sorted out.

# %% [markdown]
# ## Task 3: Understanding the data

# %%
### Task 3.1.1
# Find the number of articles
len(df_articles_filtered.index)
# Out:
# 55791

# %%
#find the number of topics
len(df_topics.index)
# Out:
# 35611
